# %% [markdown]
# # Coursera - IBM Professional Certificate - Applied Data Science Capstone Project:

# %% [markdown]
# ## Week 5 Assignment:

# %% [markdown]
# ## Peer-graded Assignment: Capstone Project - The Battle of Neighborhoods (Week 2)

# %% [markdown]
# # Title of the project : Aerial view - venues mapping support system

# %% [markdown]
# ##### Introduction / Background :
# Catalyst LLC is a new start-up company in Memphis, Tennessee, USA which provides support services to tourists & visitors as well as aiding to conduct personal/professional events and functions. Catalyst LLC has a plan to have a support system for selected option by the customer who likes to explore the city. As a small-win project, residential City of Memphis taken as a geo-location and through the coding in Python with the help of Coursera-IBM Skill lab and GitHub working out a proposal.

# %% [markdown]
# ##### About the city selected : MEMPHIS
# Memphis is a city located in Tennessee, United States of America. The city population was 650,618 in 2018.Memphis is the 26th largest city out of 314 US cities. Memphis is one of the leading commercial centers in transportation and logistics. Memphis international airport is the second busiest cargo airport in the world and the international port of Memphis is the fifth busiest inland water port in America. As on date, Memphis is a regional center for commerce, education, media, art, music and entertainment. (Note: Two memorable places in Memphis are : 1. King of rock and roll – singer and actor Elvis Presley’s and 2. The Noble Peace Prize 1964 winner for non-violence and Leader - Martin Luther King Jr.’s.) + (P.S) Interesting to note also that each and every FedEx air package in US goes through Memphis, though there are direct routes.

# %% [markdown]
# ##### Objective:
# The objective of this project is to provide management and users to view list of combined venues like food centers, cafeteria fun places, Nightlife in the selected city together with their geo-spatial data or through an aerial map to save their decision support and saving their time by avoiding one by one search.

# %% [markdown]
# ##### Data Description:
# The data used in the project is obtained from FOURSQUARE API. By using Explorer, data collected for café, restaurant, fun, nightlife , etc., for multiple searches.
#
# Link:
#
# https://foursquare.com/
#
# For the city data: Latitude: 35.122864,Longitude: -89.951860,Population: 729,307,Area: 391.55 sq. miles, Land: 386.69 sq. miles, Water: 4.86 sq. miles, Population Density: 1,886.02 people per sq. mile, Elevation: 273.0 feet above sea level . Time Zone: Central (GMT -6)
#
# Links:
#
# https://en.wikipedia.org/wiki/Memphis,_Tennessee https://en.wikipedia.org/wiki/List_of_neighborhoods_in_Memphis,_Tennessee https://en.wikipedia.org/wiki/Category:Neighborhoods_in_Memphis,_Tennessee https://en.wikipedia.org/wiki/List_of_United_States_cities_by_population
# https://open311.memphistn.gov/#!/view-data https://www.fedex.com/en-us/about/policy/aviation/why-memphis.html
#
# For Choropleth maps , geojson file of Memphis used.
#
# Python Folium library will be used to visualize the venues & allied clusters.

# %% [markdown]
# ##### Methodology proposed:
# Learning from IBM Model – CRISP (Cross Industries Standard Process) through Coursera : 1.Business Understanding 2.Analytic Approach 3.Data Requirements 4.Data Collection 5.Data Understanding 6.Data Preparation 7.Modeling 8.Evaluation 9.Deployment 10.Feedback
#
# Remember: Above 10 steps are need not to be followed strictly, in a sequence (i.e) a flexible and iterative approach.

# %% [markdown]
# ##### Table of Contents:
# Project Overview ->Data Overview ->Data Wrangling /Scraping & cleaning ->FourSquare API->Exploratory Data Analysis ->Clustering- Cluster Mapping using Folium-> Cluster Results -> Conclusion -> Assumption -> Thanking

# %% [markdown]
# ###### Coverage planned: Venues mapping –
# Food, Park, Cafeteria, Fun-Gym/Fitness center, Breakfast, Restaurants, Nightlife & my Top pick-'Museum' The following questions are to be attempted: 1.How many places or venues under each category?     . How many similar venues exist and its’ specialty ? 3. How to get ‘Birds eye view’ of their locations ?

# %% [markdown]
# ##### Scope:
# Starting with one city – Memphis but can be deployed with multiple cities optional selection by clustering in next phase, after quick-win of the project.

# %% [markdown]
# ##### Target :
# Users includes not only of our company management person but also mainly our customers and public on need (i.e) exploring different places or similar places.

# %% [markdown]
# ## 1. Importing / installing Libraries:

# %%
import pandas as pd # for data analsysis
import numpy as np # to handle data in a vectorized manner
import random # library for random number generation
import requests # to handle requests
import json
# !pip install geopy
# !pip install Nominatim
# !conda install -c conda-forge geopy --yes 
from geopy.geocoders import Nominatim # module to convert an address into latitude and longitude values
# libraries for displaying images
from IPython.display import Image 
from IPython.core.display import HTML    
#tranforming json file into a pandas dataframe library
from pandas.io.json import json_normalize
# !pip install folium
import folium # plotting library
from urllib.request import urlopen
# !pip install bs4
from bs4 import BeautifulSoup
import matplotlib.pyplot as plt
import pylab as pl
from sklearn import linear_model
from sklearn.metrics import jaccard_similarity_score
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.metrics import log_loss
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error, r2_score
import itertools
import time

print('all Libraries imported.')
# Out:
# ...
#      |████████████████████████████████| 112kB 7.5MB/s eta 0:00:01
# ...
#   Stored in directory: /home/jupyterlab/.cache/pip/wheels/d5/66/ed/e7476981dc30210b6b5ce7c25b054e8db35d44fdd2198003d4
# Successfully built Nominatim
# ...
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /home/jupyterlab/conda/envs/python
#
#   added / updated specs:
#     - geopy
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     geographiclib-1.50         |             py_0          34 KB  conda-forge
#     geopy-1.21.0               |             py_0          58 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:          92 KB
#
# The following NEW packages will be INSTALLED:
#
#   geographiclib      conda-forge/noarch::geographiclib-1.50-py_0
# ...

# %% [markdown]
# ## 2.Data

# %% [markdown]
# ## 2.1 Data Scraping and Cleaning :

# %% [markdown]
# ### For the selected city (My choice: Memphis,TN) ,obtaining its latitude & longitude :

# %% [markdown]
# ### In order to define an instance of the geocoder, we need to define a user_agent. We will name our agent foursquare_agent, as shown below.

# %%
city1 = 'Memphis, Tennessee'
geolocator = Nominatim(user_agent="foursquare_agent")
location1 = geolocator.geocode(city1)
latitude1 = location1.latitude
longitude1 = location1.longitude
print('The geograpical coordinate of {} are {}, {}.'.format(city1, latitude1, longitude1))
# Out:
# The geograpical coordinate of Memphis, Tennessee are 35.1490215, -90.0516285.

# %% [markdown]
# ### To extend to another city (for an example -my choice: Nashville,TN),obtaining its latitude & longitude :

# %%
city2 = 'Nashville, Tennessee'
geolocator = Nominatim()
location2 = geolocator.geocode(city2)
latitude2 = location2.latitude
longitude2 = location2.longitude
print('The geograpical coordinate of {} are {}, {}.'.format(city2, latitude2, longitude2))
# Out:
# /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages/ipykernel_launcher.py:2: DeprecationWarning: Using Nominatim with the default "geopy/1.21.0" `user_agent` is strongly discouraged, as it violates Nominatim's ToS https://operations.osmfoundation.org/policies/nominatim/ and may possibly cause 403 and 429 HTTP errors. Please specify a custom `user_agent` with `Nominatim(user_agent="my-application")` or by overriding the default `user_agent`: `geopy.geocoders.options.default_user_agent = "my-application"`. In geopy 2.0 this will become an exception.
# The geograpical coordinate of Nashville, Tennessee are 36.1622296, -86.7743531.

# %% [markdown]
# ### sample for adding additional city  ( 3rd city - Knoxville, TN )

# %%
city3 = 'Knoxville, Tennessee'
geolocator = Nominatim()
location3 = geolocator.geocode(city3)
latitude3 = location3.latitude
longitude3 = location3.longitude
print('The geograpical coordinate of {} are {}, {}.'.format(city3, latitude3, longitude3))
# Out:
# /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages/ipykernel_launcher.py:2: DeprecationWarning: Using Nominatim with the default "geopy/1.21.0" `user_agent` is strongly discouraged, as it violates Nominatim's ToS https://operations.osmfoundation.org/policies/nominatim/ and may possibly cause 403 and 429 HTTP errors. Please specify a custom `user_agent` with `Nominatim(user_agent="my-application")` or by overriding the default `user_agent`: `geopy.geocoders.options.default_user_agent = "my-application"`. In geopy 2.0 this will become an exception.
# The geograpical coordinate of Knoxville, Tennessee are 35.9603948, -83.9210261.

# %% [markdown]
# ## Defining Foursquare Credentials and Version:

# %%
CLIENT_ID = 'TJZPZ1S54SRN0K4YRUZR3JHSBBR05JH4B4V4KWKLBKIQDS04' # Foursquare ID
CLIENT_SECRET = 'TZN5E2IAWQR1TYI10D2DS2KYGS31RVEGMQXXISYFPDIODM1S' # Foursquare Secret CD
VERSION = '20180604' # Foursquare API version
LIMIT = 100 # limit of number of venues returned by Foursquare API
radius = 1000 # define radius
print('Your credentials:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentials:
# CLIENT_ID: TJZPZ1S54SRN0K4YRUZR3JHSBBR05JH4B4V4KWKLBKIQDS04
# CLIENT_SECRET:TZN5E2IAWQR1TYI10D2DS2KYGS31RVEGMQXXISYFPDIODM1S

# %% [markdown]
# ### Segmentation based on selected venue search : with neighborhood data - postal code and their latitude and longitude details:-

# %% [markdown]
# #### Now, let's assume that ,we are looking for food. So, let's define a query to search for food that is within 1000 metres

# %%
# creating first city (Memphis) URL
url1 = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
    CLIENT_ID, 
    CLIENT_SECRET, 
    VERSION, 
    latitude1, 
    longitude1, 
    radius, 
    LIMIT)


# creating second city (Nashville) URL
url2 = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
    CLIENT_ID, 
    CLIENT_SECRET, 
    VERSION, 
    latitude2, 
    longitude2, 
    radius, 
    LIMIT)

print(url1, url2)
# Out:
# https://api.foursquare.com/v2/venues/explore?&client_id=TJZPZ1S54SRN0K4YRUZR3JHSBBR05JH4B4V4KWKLBKIQDS04&client_secret=TZN5E2IAWQR1TYI10D2DS2KYGS31RVEGMQXXISYFPDIODM1S&v=20180604&ll=35.1490215,-90.0516285&radius=1000&limit=100 https://api.foursquare.com/v2/venues/explore?&client_id=TJZPZ1S54SRN0K4YRUZR3JHSBBR05JH4B4V4KWKLBKIQDS04&client_secret=TZN5E2IAWQR1TYI10D2DS2KYGS31RVEGMQXXISYFPDIODM1S&v=20180604&ll=36.1622296,-86.7743531&radius=1000&limit=100

# %%
# scraping the data from the generated URLs

results1 = requests.get(url1).json()
results1

results2 = requests.get(url2).json()
results2
# Out:
# {'meta': {'code': 200, 'requestId': '5e9a84e547b43d0023c66b93'},
#  'response': {'suggestedFilters': {'header': 'Tap to show:',
#    'filters': [{'name': '$-$$$$', 'key': 'price'},
#     {'name': 'Open now', 'key': 'openNow'}]},
#   'headerLocation': 'Downtown Nashville',
#   'headerFullLocation': 'Downtown Nashville, Nashville',
#   'headerLocationGranularity': 'neighborhood',
#   'totalResults': 120,
#   'suggestedBounds': {'ne': {'lat': 36.171229609000015,
#     'lng': -86.76322631384811},
#    'sw': {'lat': 36.15322959099999, 'lng': -86.78547988615189}},
#   'groups': [{'type': 'Recommended Places',
#     'name': 'recommended',
#     'items': [{'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5561141d498e5248477c42e4',
#        'name': 'The Stillery',
#        'location': {'address': '113 2nd Ave N',
#         'lat': 36.1622833923158,
# ...

# %%
# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# %%
# first city - Memphis # 
venues1 = results1['response']['groups'][0]['items']
nearby_venues1 = json_normalize(venues1) # flatten JSON

# filtering columns
filtered_columns1 = ['venue.name', 'venue.categories', 'venue.location.lat', 
                    'venue.location.lng', 'venue.id']
nearby_venues1 =nearby_venues1.loc[:, filtered_columns1]

# filtering the category for each row
nearby_venues1['venue.categories'] = nearby_venues1.apply(get_category_type, axis=1)

# cleaning columns
nearby_venues1.columns = [col.split(".")[-1] for col in nearby_venues1.columns]
# Out:
# /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages/ipykernel_launcher.py:3: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
# Printing the count 
print('{} venues were returned by Foursquare.'.format(nearby_venues1.shape[0]))
# Out:
# 77 venues were returned by Foursquare.

# %%
# second city - Nashville #
venues2 = results2['response']['groups'][0]['items']
nearby_venues2 = json_normalize(venues2) # flatten JSON

# filtering columns
filtered_columns2 = ['venue.name', 'venue.categories', 'venue.location.lat', 
                    'venue.location.lng', 'venue.id']
nearby_venues2 =nearby_venues2.loc[:, filtered_columns2]

# filtering the category for each row
nearby_venues2['venue.categories'] = nearby_venues2.apply(get_category_type, axis=1)

# cleaning columns
nearby_venues2.columns = [col.split(".")[-1] for col in nearby_venues2.columns]
# Out:
# /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages/ipykernel_launcher.py:3: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
# Printing the count 
print('{} venues were returned by Foursquare.'.format(nearby_venues2.shape[0]))
# Out:
# 100 venues were returned by Foursquare.

# %%
# adding locations data to the data sets of each city
nearby_venues1['city'] = 'Memphis'
nearby_venues2['city'] = 'Nashville'

# %%
# combining the two cities into one data set
nearby_venues = nearby_venues1.copy()
nearby_venues = nearby_venues.append(nearby_venues2)

# %%
nearby_venues.head()
# Out:
#                                     name          categories        lat  \
# 0  Cannon Center For The Performing Arts        Concert Hall  35.150488
# 1                                  Qahwa         Coffee Shop  35.148373
# 2                           Court Square                Park  35.146040
# 3               Rachel's Salon & Day Spa  Salon / Barbershop  35.145709
# 4                Maciel's Tortas & Tacos  Mexican Restaurant  35.144000
#
#          lng                        id     city
# 0 -90.051605  4b058663f964a520e55f22e3  Memphis
# 1 -90.051681  4f9880f6e4b05f758cb507fc  Memphis
# 2 -90.051906  4b058661f964a5205a5f22e3  Memphis
# 3 -90.052597  4b78671bf964a5209ecb2ee3  Memphis
# 4 -90.053038  5612b256498e2a8fc88814fd  Memphis

# %%
nearby_venues.tail()
# Out:
#                               name          categories        lat        lng  \
# 95               Titans Club Level  Athletics & Sports  36.166240 -86.772420
# 96                       Limelight             Theater  36.169761 -86.770818
# 97               Salon J & Day Spa  Salon / Barbershop  36.165699 -86.779446
# 98                    The Hot Spot          Food Truck  36.166296 -86.778724
# 99  Jack Daniel's Titan's Tailgate    Football Stadium  36.165582 -86.768334
#
#                           id       city
# 95  526421c411d290190e29f617  Nashville
# 96  4b058670f964a520536222e3  Nashville
# 97  4cd574beab19a0931a3e3feb  Nashville
# 98  4f19b794e4b0b62f9b9f3523  Nashville
# 99  50bb8550e4b062ae37fe3c58  Nashville

# %%
nearby_venues.shape
# Out:
# (177, 6)

# %%
nearby_venues.describe()
# Out:
#               lat         lng
# count  177.000000  177.000000
# mean    35.720343  -88.201267
# std      0.504560    1.628252
# min     35.140169  -90.058965
# 25%     35.146794  -90.051905
# 50%     36.156557  -86.782506
# 75%     36.163116  -86.775956
# max     36.169761  -86.764712

# %%
nearby_venues.dtypes
# Out:
# name           object
# categories     object
# lat           float64
# lng           float64
# id             object
# city           object
# dtype: object

# %%
len(nearby_venues)
# Out:
# 177

# %%
nearby_venues.columns
# Out:
# Index(['name', 'categories', 'lat', 'lng', 'id', 'city'], dtype='object')

# %%
# Printing the count for cross checking reference  
print('{} venues were returned by Foursquare.'.format(nearby_venues1.shape[0]))
print('{} venues were returned by Foursquare.'.format(nearby_venues2.shape[0]))
# Out:
# 77 venues were returned by Foursquare.
# 100 venues were returned by Foursquare.

# %%
nearby_venues[['name','categories','city','lat','lng']]
# Out:
#                                      name          categories       city  \
# 0   Cannon Center For The Performing Arts        Concert Hall    Memphis
# 1                                   Qahwa         Coffee Shop    Memphis
# 2                            Court Square                Park    Memphis
# 3                Rachel's Salon & Day Spa  Salon / Barbershop    Memphis
# 4                 Maciel's Tortas & Tacos  Mexican Restaurant    Memphis
# ..                                    ...                 ...        ...
# 95                      Titans Club Level  Athletics & Sports  Nashville
# 96                              Limelight             Theater  Nashville
# 97                      Salon J & Day Spa  Salon / Barbershop  Nashville
# 98                           The Hot Spot          Food Truck  Nashville
# 99         Jack Daniel's Titan's Tailgate    Football Stadium  Nashville
#
#           lat        lng
# 0   35.150488 -90.051605
# 1   35.148373 -90.051681
# ...

# %%
nearby_venues['categories'].unique
# Out:
# <bound method Series.unique of 0           Concert Hall
# 1            Coffee Shop
# 2                   Park
# 3     Salon / Barbershop
# 4     Mexican Restaurant
#              ...
# 95    Athletics & Sports
# 96               Theater
# 97    Salon / Barbershop
# 98            Food Truck
# 99      Football Stadium
# Name: categories, Length: 177, dtype: object>

# %%
unique_cat_list = nearby_venues['categories'].unique()

# %%
unique_cat_list
# Out:
# array(['Concert Hall', 'Coffee Shop', 'Park', 'Salon / Barbershop',
#        'Mexican Restaurant', 'Tapas Restaurant', 'Bar', 'Pub', 'Trail',
#        'American Restaurant', 'Cuban Restaurant', 'Hotel',
#        'Gym / Fitness Center', 'Baseball Stadium',
#        'Southern / Soul Food Restaurant', 'Sandwich Place',
#        'Seafood Restaurant', 'Roof Deck', 'Pizza Place', 'Burger Joint',
#        'Cocktail Bar', 'Rest Area', 'Sporting Goods Shop',
#        'Brazilian Restaurant', 'Café', 'Gym', 'BBQ Joint', 'Smoke Shop',
#        'Speakeasy', 'Lounge', 'Beer Garden', 'Event Space',
#        'Sushi Restaurant', 'Food Court', 'Shopping Mall', 'Karaoke Bar',
#        'Museum', 'Liquor Store', 'Theme Restaurant',
#        'Fried Chicken Joint', 'Fast Food Restaurant', 'Hotel Bar',
#        'Harbor / Marina', "Men's Store", 'Boat or Ferry',
#        'Scenic Lookout', 'Gas Station', 'Music Venue', 'Intersection',
# ...

# %% [markdown]
#  ### As mentioned , for this project considering the scope, taken only first city -'Memphis' for further proceeding

# %%
Memphis_unique_cat_list = nearby_venues1['categories'].unique()

# %%
Memphis_unique_cat_list
# Out:
# array(['Concert Hall', 'Coffee Shop', 'Park', 'Salon / Barbershop',
#        'Mexican Restaurant', 'Tapas Restaurant', 'Bar', 'Pub', 'Trail',
#        'American Restaurant', 'Cuban Restaurant', 'Hotel',
#        'Gym / Fitness Center', 'Baseball Stadium',
#        'Southern / Soul Food Restaurant', 'Sandwich Place',
#        'Seafood Restaurant', 'Roof Deck', 'Pizza Place', 'Burger Joint',
#        'Cocktail Bar', 'Rest Area', 'Sporting Goods Shop',
#        'Brazilian Restaurant', 'Café', 'Gym', 'BBQ Joint', 'Smoke Shop',
#        'Speakeasy', 'Lounge', 'Beer Garden', 'Event Space',
#        'Sushi Restaurant', 'Food Court', 'Shopping Mall', 'Karaoke Bar',
#        'Museum', 'Liquor Store', 'Theme Restaurant',
#        'Fried Chicken Joint', 'Fast Food Restaurant', 'Hotel Bar',
#        'Harbor / Marina', "Men's Store", 'Boat or Ferry',
#        'Scenic Lookout', 'Gas Station', 'Music Venue', 'Intersection',
#        'Department Store'], dtype=object)

# %% [markdown]
# ## 2.2 Data Preparation:

# %% [markdown]
# ## First Search - 'Food':

# %%
# search for Food
search_query = 'Food'
radius = 1000
print(search_query + ' .... OK!')
# Out:
# Food .... OK!

# %%
# Define the corresponding URL
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude1, longitude1, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=TJZPZ1S54SRN0K4YRUZR3JHSBBR05JH4B4V4KWKLBKIQDS04&client_secret=TZN5E2IAWQR1TYI10D2DS2KYGS31RVEGMQXXISYFPDIODM1S&ll=35.1490215,-90.0516285&v=20180604&query=Food&radius=1000&limit=100'

# %% [markdown]
# ## Cleaning data frame of the first search - 'Food':

# %%
# Send the GET Request and examine the results
food = requests.get(url).json()
food
# Out:
# {'meta': {'code': 200, 'requestId': '5e9a84afc94979001b5122d6'},
#  'response': {'venues': [{'id': '5047e6ece4b03af1df58f318',
#     'name': 'StickEm Food Truck',
#     'location': {'lat': 35.14600260893158,
#      'lng': -90.05145453698302,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 35.14600260893158,
#        'lng': -90.05145453698302}],
#      'distance': 336,
#      'postalCode': '38104',
#      'cc': 'US',
#      'city': 'Memphis',
#      'state': 'TN',
#      'country': 'United States',
#      'formattedAddress': ['Memphis, TN 38104', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1cb941735',
#       'name': 'Food Truck',
#       'pluralName': 'Food Trucks',
#       'shortName': 'Food Truck',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/streetfood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '51031045'},
#     'referralId': 'v-1587184839',
#     'hasPerk': False},
# ...

# %% [markdown]
# Getting relevant part of JSON and transforming it into a pandas dataframe

# %%
# assign relevant part of JSON to venues
venues = food['response']['venues']

# tranform venues into a dataframe
dataframe = json_normalize(venues)
dataframe.head()
# Out:
# /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages/ipykernel_launcher.py:5: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   """
#                          id                  name  \
# 0  5047e6ece4b03af1df58f318    StickEm Food Truck
# 1  4e9c5a0e775b2c05ae91caf1     Premier Soul Food
# 2  4f321caf19836c91c7b719a6  Easy Way Food Stores
# 3  4b534d9ef964a5205d9627e3           Jack's Food
# 4  5790f9a1498e0a2fc186ef62   Food Truck Thursday
#
#                                           categories    referralId  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d1cb941735', 'name': 'F...  v-1587184839    False
# 1  [{'id': '4bf58dd8d48988d14f941735', 'name': 'S...  v-1587184839    False
# 2  [{'id': '4d4b7105d754a06374d81259', 'name': 'F...  v-1587184839    False
# 3  [{'id': '4bf58dd8d48988d118951735', 'name': 'G...  v-1587184839    False
# 4  [{'id': '4bf58dd8d48988d1cb941735', 'name': 'F...  v-1587184839    False
#
# ...

# %%
# keeping only columns that include venue name, and anything that is associated with location
clean_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')]+ ['id']
clean_dataframe = dataframe.loc[:,clean_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filtering the category for each row
clean_dataframe['categories'] = clean_dataframe.apply(get_category_type, axis=1)

# cleaning column names by keeping only last term
clean_dataframe.columns = [column.split('.')[-1] for column in clean_dataframe.columns]

clean_dataframe.head()
# Out:
#                    name                       categories        lat  \
# 0    StickEm Food Truck                       Food Truck  35.146003
# 1     Premier Soul Food  Southern / Soul Food Restaurant  35.149563
# 2  Easy Way Food Stores                             Food  35.147379
# 3           Jack's Food                    Grocery Store  35.147421
# 4   Food Truck Thursday                       Food Truck  35.146180
#
#          lng                                     labeledLatLngs  distance  \
# 0 -90.051455  [{'label': 'display', 'lat': 35.14600260893158...       336
# 1 -90.050003  [{'label': 'display', 'lat': 35.14956283569336...       159
# 2 -90.051552  [{'label': 'display', 'lat': 35.147379, 'lng':...       182
# 3 -90.051970  [{'label': 'display', 'lat': 35.14742136962383...       180
# 4 -90.052576  [{'label': 'display', 'lat': 35.14617959626494...       327
#
#   postalCode  cc     city      state        country  \
# 0      38104  US  Memphis         TN  United States
# ...

# %%
# deleting unnecessary columns
clean_dataframe2= clean_dataframe.drop(['cc','country', 'crossStreet', 'distance', 'formattedAddress',\
                                        'labeledLatLngs', 'id'], axis=1)
clean_dataframe
# Out:
#                                  name                       categories  \
# 0                  StickEm Food Truck                       Food Truck
# 1                   Premier Soul Food  Southern / Soul Food Restaurant
# 2                Easy Way Food Stores                             Food
# 3                         Jack's Food                    Grocery Store
# 4                 Food Truck Thursday                       Food Truck
# 5                  Crumpys Food Truck              American Restaurant
# 6             Quincy's BBQ Food Truck                       Food Truck
# 7                                food                        BBQ Joint
# 8                 Grisanti Food Truck                       Food Truck
# 9                     Stix Food Truck                       Food Truck
# 10              Revival Southern Food                       Food Truck
# 11      Healthy Life Styles Food Bstr                             Food
# ...

# %%
# deleting rows with none values
clean_dataframe3 = clean_dataframe2.dropna(axis=0, how='any', thresh=None, subset=None, inplace=False)
clean_dataframe3
# Out:
#                              name                       categories        lat  \
# 2            Easy Way Food Stores                             Food  35.147379
# 3                     Jack's Food                    Grocery Store  35.147421
# 11  Healthy Life Styles Food Bstr                             Food  35.143946
# 12               Gli Food Service                             Food  35.142295
# 17              Alfred's on Beale                              Bar  35.139356
# 18    Miss Polly's Soul City Cafe  Southern / Soul Food Restaurant  35.139881
# 19                 Ultimate Foods                       Restaurant  35.145068
#
#           lng postalCode     city state        address
# 2  -90.051552      38103  Memphis    TN   80 N Main St
# 3  -90.051970      38103  Memphis    TN   84 N Main St
# 11 -90.053421      38103  Memphis    TN   45 S Main St
# 12 -90.050066      38103  Memphis    TN  203 Union Ave
# 17 -90.051506      38103  Memphis    TN   197 Beale St
# ...

# %%
# deleting rows which its category is not Food 
array= ['Food']
food_dataframe= clean_dataframe3.loc[clean_dataframe3['categories'].isin(array)]
food_dataframe
# Out:
#                              name categories        lat        lng postalCode  \
# 2            Easy Way Food Stores       Food  35.147379 -90.051552      38103
# 11  Healthy Life Styles Food Bstr       Food  35.143946 -90.053421      38103
# 12               Gli Food Service       Food  35.142295 -90.050066      38103
#
#        city state        address
# 2   Memphis    TN   80 N Main St
# 11  Memphis    TN   45 S Main St
# 12  Memphis    TN  203 Union Ave

# %%
# checking and deleting rows if name is more than one count
df_food = food_dataframe.drop_duplicates(subset='name', keep="first")
df_food
# Out:
#                              name categories        lat        lng postalCode  \
# 2            Easy Way Food Stores       Food  35.147379 -90.051552      38103
# 11  Healthy Life Styles Food Bstr       Food  35.143946 -90.053421      38103
# 12               Gli Food Service       Food  35.142295 -90.050066      38103
#
#        city state        address
# 2   Memphis    TN   80 N Main St
# 11  Memphis    TN   45 S Main St
# 12  Memphis    TN  203 Union Ave

# %% [markdown]
# ## Second search :' Park':

# %%
# search for Parks
search_query = 'Park'
radius = 10000

# Defining the corresponding URL
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'\
.format(CLIENT_ID, CLIENT_SECRET, latitude1, longitude1, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=TJZPZ1S54SRN0K4YRUZR3JHSBBR05JH4B4V4KWKLBKIQDS04&client_secret=TZN5E2IAWQR1TYI10D2DS2KYGS31RVEGMQXXISYFPDIODM1S&ll=35.1490215,-90.0516285&v=20180604&query=Park&radius=10000&limit=100'

# %% [markdown]
# Cleaning data frame of the second search - 'Park':

# %%
# Sending the GET Request and examining the results
park = requests.get(url).json()
park
# Out:
# {'meta': {'code': 200, 'requestId': '5e9a84bb9da7ee001bbb044f'},
#  'response': {'venues': [{'id': '4c51a454375c0f47041b5294',
#     'name': 'Memphis Park',
#     'location': {'address': '51 Front St',
#      'crossStreet': 'at Jefferson Ave.',
#      'lat': 35.14673206107226,
#      'lng': -90.05406726847882,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 35.14673206107226,
#        'lng': -90.05406726847882}],
#      'distance': 337,
#      'postalCode': '38103',
#      'cc': 'US',
#      'city': 'Memphis',
#      'state': 'TN',
#      'country': 'United States',
#      'formattedAddress': ['51 Front St (at Jefferson Ave.)',
#       'Memphis, TN 38103',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d163941735',
#       'name': 'Park',
#       'pluralName': 'Parks',
#       'shortName': 'Park',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/park_',
#        'suffix': '.png'},
#       'primary': True}],
# ...

# %%
# assigning relevant part of JSON to venues
venues = park['response']['venues']

# tranforming venues into a dataframe
park_dataframe = json_normalize(venues)
park_dataframe.head()
# Out:
# /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages/ipykernel_launcher.py:5: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   """
#                          id                              name  \
# 0  4c51a454375c0f47041b5294                      Memphis Park
# 1  4b058661f964a5205b5f22e3                      Tom Lee Park
# 2  4b155022f964a520f6af23e3                     AutoZone Park
# 3  4b6dc84cf964a5205e8f2ce3  Mississippi River Greenbelt Park
# 4  4b57c713f964a520954028e3                 Edison Park Apts.
#
#                                           categories    referralId  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d163941735', 'name': 'P...  v-1587184842    False
# 1  [{'id': '4bf58dd8d48988d163941735', 'name': 'P...  v-1587184842    False
# 2  [{'id': '4bf58dd8d48988d18c941735', 'name': 'B...  v-1587184842    False
# 3  [{'id': '4bf58dd8d48988d163941735', 'name': 'P...  v-1587184842    False
# ...

# %%
# keeping only columns that include venue name, and anything that is associated with location
park_clean_columns = ['name', 'categories'] + [col for col in park_dataframe.columns if col.startswith('location.')]+ ['id']
clean_park_dataframe = park_dataframe.loc[:,park_clean_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list1 = row['categories']
    except:
        categories_list1 = row['venue.categories']
        
    if len(categories_list1) == 0:
        return None
    else:
        return categories_list1[0]['name']

# filtering the category for each row
clean_park_dataframe['categories'] = clean_park_dataframe.apply(get_category_type, axis=1)

# cleaning column names by keeping only last term
clean_park_dataframe.columns = [column.split('.')[-1] for column in clean_park_dataframe.columns]

clean_park_dataframe.head()
# Out:
#                                name                                categories  \
# 0                      Memphis Park                                      Park
# 1                      Tom Lee Park                                      Park
# 2                     AutoZone Park                          Baseball Stadium
# 3  Mississippi River Greenbelt Park                                      Park
# 4                 Edison Park Apts.  Residential Building (Apartment / Condo)
#
#                    address        crossStreet        lat        lng  \
# 0              51 Front St  at Jefferson Ave.  35.146732 -90.054067
# 1  357 South Riverside Dr.                NaN  35.136636 -90.062896
# 2            200 Union Ave        at S 3rd St  35.142748 -90.049884
# 3               Mud Island                NaN  35.173387 -90.055146
# 4        595 Jefferson Ave          Techno Dr  35.143486 -90.040912
#
#                                       labeledLatLngs  distance postalCode  cc  \
# ...

# %%
# deleting unnecessary columns
clean_park_dataframe2= clean_park_dataframe.drop(['cc','crossStreet','neighborhood', 'country', 'distance', 'formattedAddress',''\
                                        'labeledLatLngs', 'id'], axis=1)
clean_park_dataframe2
# Out:
#                                           name  \
# 0                                 Memphis Park
# 1                                 Tom Lee Park
# 2                                AutoZone Park
# 3             Mississippi River Greenbelt Park
# 4                            Edison Park Apts.
# 5                           Robert Church Park
# 6                             Harbor Isle Park
# 7                        Mud Island River Park
# 8                         Health Sciences Park
# 9                         Jefferson Davis Park
# 10                                Audubon Park
# 11                                Legends Park
# 12                   Christopher Columbus Park
# 13                                   Best Park
# 14                               PARK(ING) Day
# 15                                Overton Park
# 16                      Mississippi River Park
# 17                                Parkway Park
# 18              Island Park/Harbor Town Square
# ...

# %%
# deleting rows with none values
clean_park_dataframe3 = clean_park_dataframe2.dropna(axis=0, how='any', thresh=None, subset=None, inplace=False)
clean_park_dataframe3
# Out:
#                                 name  \
# 0                       Memphis Park
# 1                       Tom Lee Park
# 2                      AutoZone Park
# 3   Mississippi River Greenbelt Park
# 4                  Edison Park Apts.
# 5                 Robert Church Park
# 7              Mud Island River Park
# 11                      Legends Park
# 15                      Overton Park
# 16            Mississippi River Park
# 18    Island Park/Harbor Town Square
# 20                        Handy Park
# 28                        Vance Park
# 29        AutoZone Headquarters Park
# 30                     Colonial Park
# 32   Park Express (Park Food & Fuel)
# 40             Park Tower Apartments
# 43                     Founders Park
# 46                      Village Park
# 48                         Navy park
# 49                   Washington Park
#
#                                   categories                  address  \
# ...

# %%
# deleting rows which its category is not Park
df_park = clean_park_dataframe3[clean_park_dataframe3.categories == 'Park']
df_park
# Out:
#                                 name categories                  address  \
# 0                       Memphis Park       Park              51 Front St
# 1                       Tom Lee Park       Park  357 South Riverside Dr.
# 3   Mississippi River Greenbelt Park       Park               Mud Island
# 5                 Robert Church Park       Park             Beale Street
# 7              Mud Island River Park       Park           125 N Front St
# 15                      Overton Park       Park          2080 Poplar Ave
# 16            Mississippi River Park       Park    51 N. Riverside Drive
# 20                        Handy Park       Park             200 Beale St
# 29        AutoZone Headquarters Park       Park             Wagner Place
# 30                     Colonial Park       Park      AW Willis & Main St
# 43                     Founders Park       Park               South Main
# 48                         Navy park       Park            S. 2nd street
#
# ...

# %% [markdown]
# ## Third search - 'Restaurant':

# %%
# searching for Restaurants
search_query = 'Restaurant'
radius = 10000

# %%
# Defining the corresponding URL
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude1, longitude1, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=TJZPZ1S54SRN0K4YRUZR3JHSBBR05JH4B4V4KWKLBKIQDS04&client_secret=TZN5E2IAWQR1TYI10D2DS2KYGS31RVEGMQXXISYFPDIODM1S&ll=35.1490215,-90.0516285&v=20180604&query=Restaurant&radius=10000&limit=100'

# %%
# Sending the GET Request and examining the results
Restaurant = requests.get(url).json()
Restaurant
# Out:
# {'meta': {'code': 200, 'requestId': '5e9a847878a484001bf28623'},
#  'response': {'venues': [{'id': '4c76a4d73adda14383a70aaf',
#     'name': 'Flight Restaurant and Wine Bar',
#     'location': {'address': '39 S Main St',
#      'crossStreet': 'at Monroe Ave',
#      'lat': 35.14426004351449,
#      'lng': -90.0532968227515,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 35.14426004351449,
#        'lng': -90.0532968227515}],
#      'distance': 551,
#      'postalCode': '38103',
#      'cc': 'US',
#      'city': 'Memphis',
#      'state': 'TN',
#      'country': 'United States',
#      'formattedAddress': ['39 S Main St (at Monroe Ave)',
#       'Memphis, TN 38103',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1db931735',
#       'name': 'Tapas Restaurant',
#       'pluralName': 'Tapas Restaurants',
#       'shortName': 'Tapas',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/tapas_',
#        'suffix': '.png'},
# ...

# %% [markdown]
# Cleaning data frame of the third search - 'Restaurant':

# %%
# assigning relevant part of JSON to venues
venues = Restaurant['response']['venues']

# tranforming venues into a dataframe
Restaurant_dataframe = json_normalize(venues)
Restaurant_dataframe.head()
# Out:
# /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages/ipykernel_launcher.py:5: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   """
#                          id                              name  \
# 0  4c76a4d73adda14383a70aaf    Flight Restaurant and Wine Bar
# 1  4ea0b36ee5fa4ad9cf636931        Bleu Restaurant and Lounge
# 2  4b75792ff964a520810e2ee3                 Arcade Restaurant
# 3  4f321a0219836c91c7b5ffc3               Gridiron Restaurant
# 4  4fac0d2fe4b0bcc0c130f189  Willie Moore's Family Restaurant
#
#                                           categories    referralId  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d1db931735', 'name': 'T...  v-1587184843    False
# 1  [{'id': '4bf58dd8d48988d14e941735', 'name': 'A...  v-1587184843    False
# 2  [{'id': '4bf58dd8d48988d143941735', 'name': 'B...  v-1587184843    False
# 3  [{'id': '4d4b7105d754a06374d81259', 'name': 'F...  v-1587184843    False
# ...

# %%
# keeing only columns that include venue name, and anything that is associated with location
Restaurant_clean_columns = ['name', 'categories'] + [col for col in Restaurant_dataframe.columns if col.startswith('location.')]+ ['id']
clean_Restaurant_dataframe = Restaurant_dataframe.loc[:,Restaurant_clean_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list3 = row['categories']
    except:
        categories_list3 = row['venue.categories']
        
    if len(categories_list3) == 0:
        return None
    else:
        return categories_list3[0]['name']

# filtering the category for each row
clean_Restaurant_dataframe['categories'] = clean_Restaurant_dataframe.apply(get_category_type, axis=1)

# cleaning column names by keeping only last term
clean_Restaurant_dataframe.columns = [column.split('.')[-1] for column in clean_Restaurant_dataframe.columns]

clean_Restaurant_dataframe.head()
# Out:
#                                name                       categories  \
# 0    Flight Restaurant and Wine Bar                 Tapas Restaurant
# 1        Bleu Restaurant and Lounge              American Restaurant
# 2                 Arcade Restaurant                   Breakfast Spot
# 3               Gridiron Restaurant                             Food
# 4  Willie Moore's Family Restaurant  Southern / Soul Food Restaurant
#
#           address    crossStreet        lat        lng  \
# 0    39 S Main St  at Monroe Ave  35.144260 -90.053297
# 1    221 S 3rd St            NaN  35.138975 -90.052381
# 2   540 S Main St   GE Patterson  35.132748 -90.058863
# 3  100 N Front St            NaN  35.147857 -90.052471
# 4             NaN            NaN  35.147945 -90.051740
#
#                                       labeledLatLngs  distance postalCode  cc  \
# 0  [{'label': 'display', 'lat': 35.14426004351449...       551      38103  US
# ...

# %%
# deleting unnecessary columns
clean_Restaurant_dataframe2= clean_Restaurant_dataframe.drop(['cc', 'country', 'crossStreet', 'distance', 'formattedAddress',\
                                        'labeledLatLngs', 'id'], axis=1)
clean_Restaurant_dataframe2
# Out:
#                                            name  \
# 0                Flight Restaurant and Wine Bar
# 1                    Bleu Restaurant and Lounge
# 2                             Arcade Restaurant
# 3                           Gridiron Restaurant
# 4              Willie Moore's Family Restaurant
# 5                               SAGE Restaurant
# 6                             Huey's Restaurant
# 7             Ms. Girlee's Soul Food Restaurant
# 8                  Felicia Suzanne's Restaurant
# 9                         Luna Bar & Restaurant
# 10        Notes & Provisions Restaurant and Bar
# 11                    Smitty's Place Restaurant
# 12                    Harbor Landing Restaurant
# 13                     Erikas German Restaurant
# 14              Orleans On The Front Restaurant
# 15                      Cayenne Moon Restaurant
# 16             Christian Supper Club Restaurant
# 17            Gordon Biersch Brewery Restaurant
# ...

# %%
# deleting rows with none values
df_Restaurant = clean_Restaurant_dataframe2.dropna(axis=0, how='any', thresh=None, subset=None, inplace=False)
df_Restaurant
# Out:
#                                            name  \
# 0                Flight Restaurant and Wine Bar
# 1                    Bleu Restaurant and Lounge
# 2                             Arcade Restaurant
# 3                           Gridiron Restaurant
# 5                               SAGE Restaurant
# 6                             Huey's Restaurant
# 7             Ms. Girlee's Soul Food Restaurant
# 8                  Felicia Suzanne's Restaurant
# 10        Notes & Provisions Restaurant and Bar
# 11                    Smitty's Place Restaurant
# 12                    Harbor Landing Restaurant
# 13                     Erikas German Restaurant
# 14              Orleans On The Front Restaurant
# 15                      Cayenne Moon Restaurant
# 16             Christian Supper Club Restaurant
# 17            Gordon Biersch Brewery Restaurant
# 18                               A&W Restaurant
# 19                 Shanghai Oriental Restaurant
# ...

# %% [markdown]
# ## Fourth search: 'Cafeteria'

# %%
# searching for Cafeteria
search_query = 'Cafeteria'
radius = 10000

# %%
# Defining the corresponding URL
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude1, longitude1, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=TJZPZ1S54SRN0K4YRUZR3JHSBBR05JH4B4V4KWKLBKIQDS04&client_secret=TZN5E2IAWQR1TYI10D2DS2KYGS31RVEGMQXXISYFPDIODM1S&ll=35.1490215,-90.0516285&v=20180604&query=Cafeteria&radius=10000&limit=100'

# %%
# Sending the GET Request and examining the results
Cafeteria = requests.get(url).json()
Cafeteria
# Out:
# {'meta': {'code': 200, 'requestId': '5e9a854b1a4b0a001bf52fad'},
#  'response': {'venues': [{'id': '4cd18f676200b1f77f92da28',
#     'name': 'Premier Cafeteria',
#     'location': {'address': '109 N Main St',
#      'lat': 35.147857,
#      'lng': -90.052471,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 35.147857,
#        'lng': -90.052471}],
#      'distance': 150,
#      'postalCode': '38103',
#      'cc': 'US',
#      'city': 'Memphis',
#      'state': 'TN',
#      'country': 'United States',
#      'formattedAddress': ['109 N Main St',
#       'Memphis, TN 38103',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1587184844',
#     'hasPerk': False},
#    {'id': '4c2832b79fb5d13a1c4b9957',
# ...

# %% [markdown]
# ### Cleaning the data frame of fourth search - 'Cafeteria':

# %%
# assigning relevant part of JSON to venues
venues = Cafeteria['response']['venues']

# %%
# tranforming venues into a dataframe
Cafeteria_dataframe = json_normalize(venues)
Cafeteria_dataframe.head()
# Out:
# /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages/ipykernel_launcher.py:2: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#                          id                    name  \
# 0  4cd18f676200b1f77f92da28       Premier Cafeteria
# 1  4c2832b79fb5d13a1c4b9957  Peeples Stag Cafeteria
# 2  4ed102a8be7b9eece0a994c8     LeBonheur Cafeteria
# 3  4f3d5980e4b02d5ef898e188       The MED Cafeteria
# 4  4ffa2227e4b02b971671ac38           CBU Cafeteria
#
#                                           categories    referralId  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d16d941735', 'name': 'C...  v-1587184844    False
# 1                                                 []  v-1587184844    False
# 2  [{'id': '4bf58dd8d48988d120951735', 'name': 'F...  v-1587184844    False
# 3  [{'id': '4bf58dd8d48988d120951735', 'name': 'F...  v-1587184844    False
# 4  [{'id': '4bf58dd8d48988d1a1941735', 'name': 'C...  v-1587184844    False
#
# ...

# %%
# keeping only columns that include venue name, and anything that is associated with location
Cafeteria_clean_columns = ['name', 'categories'] + [col for col in Cafeteria_dataframe.columns if col.startswith('location.')]+ ['id']
clean_Cafeteria_dataframe = Cafeteria_dataframe.loc[:,Cafeteria_clean_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list4 = row['categories']
    except:
        categories_list4 = row['venue.categories']
        
    if len(categories_list4) == 0:
        return None
    else:
        return categories_list4[0]['name']

# filtering the category for each row
clean_Cafeteria_dataframe['categories'] = clean_Cafeteria_dataframe.apply(get_category_type, axis=1)

# cleaning column names by keeping only last term
clean_Cafeteria_dataframe.columns = [column.split('.')[-1] for column in clean_Cafeteria_dataframe.columns]

clean_Cafeteria_dataframe.head()
# Out:
#                      name         categories                     address  \
# 0       Premier Cafeteria               Café               109 N Main St
# 1  Peeples Stag Cafeteria               None                         NaN
# 2     LeBonheur Cafeteria         Food Court                         NaN
# 3       The MED Cafeteria         Food Court  Jefferson Ave, Memphis, TN
# 4           CBU Cafeteria  College Cafeteria                         NaN
#
#          lat        lng                                     labeledLatLngs  \
# 0  35.147857 -90.052471  [{'label': 'display', 'lat': 35.147857, 'lng':...
# 1  35.139359 -90.050429  [{'label': 'display', 'lat': 35.13935919863707...
# 2  35.144849 -90.032197  [{'label': 'display', 'lat': 35.1448487970461,...
# 3  35.142368 -90.031839  [{'label': 'display', 'lat': 35.14236833230642...
# 4  35.126973 -89.981552  [{'label': 'display', 'lat': 35.126973, 'lng':...
#
#    distance postalCode  cc     city      state        country  \
# ...

# %%
# deleting unnecessary columns
clean_Cafeteria_dataframe2= clean_Cafeteria_dataframe.drop(['cc', 'country','crossStreet', 'distance', 'formattedAddress',\
                                        'labeledLatLngs', 'id'], axis=1)
clean_Cafeteria_dataframe2
# Out:
#                               name           categories  \
# 0                Premier Cafeteria                 Café
# 1           Peeples Stag Cafeteria                 None
# 2              LeBonheur Cafeteria           Food Court
# 3                The MED Cafeteria           Food Court
# 4                    CBU Cafeteria    College Cafeteria
# 5                Peabody Cafeteria            Cafeteria
# 6             Piccadilly Cafeteria  American Restaurant
# 7  Medtronic Bon Appetit Cafeteria            Cafeteria
# 8          Fedex Cafeteria Aramark            Cafeteria
# 9             Piccadilly Cafeteria  American Restaurant
#
#                       address        lat        lng postalCode     city  \
# 0               109 N Main St  35.147857 -90.052471      38103  Memphis
# 1                         NaN  35.139359 -90.050429        NaN      NaN
# 2                         NaN  35.144849 -90.032197      38105  Memphis
# ...

# %%
# deleting rows with none values
df_Cafeteria = clean_Cafeteria_dataframe2.dropna(axis=0, how='any', thresh=None, subset=None, inplace=False)
df_Cafeteria
# Out:
#                    name           categories                     address  \
# 0     Premier Cafeteria                 Café               109 N Main St
# 3     The MED Cafeteria           Food Court  Jefferson Ave, Memphis, TN
# 5     Peabody Cafeteria            Cafeteria                       Young
# 6  Piccadilly Cafeteria  American Restaurant             3425 Poplar Ave
# 9  Piccadilly Cafeteria  American Restaurant     3968 Elvis Presley Blvd
#
#          lat        lng postalCode     city state
# 0  35.147857 -90.052471      38103  Memphis    TN
# 3  35.142368 -90.031839      38105  Memphis    TN
# 5  35.120480 -89.992474      38104  Memphis    TN
# 6  35.127871 -89.947685      38111  Memphis    TN
# 9  35.039954 -90.024753      38116  Memphis    TN

# %% [markdown]
# ## Fifth Search for 'my Top Pick-Museum' :

# %%
# searching for my Top Pick-Museum
search_query = 'Museum'
radius = 1000

# Defining the corresponding URL
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude1, longitude1, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=TJZPZ1S54SRN0K4YRUZR3JHSBBR05JH4B4V4KWKLBKIQDS04&client_secret=TZN5E2IAWQR1TYI10D2DS2KYGS31RVEGMQXXISYFPDIODM1S&ll=35.1490215,-90.0516285&v=20180604&query=Museum&radius=1000&limit=100'

# %%
# Send the GET Request and examine the results
Top_picks= requests.get(url).json()
Top_picks
# Out:
# {'meta': {'code': 200, 'requestId': '5e9a83e5b4b684001cbf7f78'},
#  'response': {'venues': [{'id': '4b058660f964a5204b5f22e3',
#     'name': 'Fire Museum of Memphis',
#     'location': {'address': '118 Adams Ave',
#      'lat': 35.148367,
#      'lng': -90.050699,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 35.148367,
#        'lng': -90.050699},
#       {'label': 'entrance', 'lat': 35.148182, 'lng': -90.050595}],
#      'distance': 111,
#      'postalCode': '38103',
#      'cc': 'US',
#      'city': 'Memphis',
#      'state': 'TN',
#      'country': 'United States',
#      'formattedAddress': ['118 Adams Ave',
#       'Memphis, TN 38103',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d190941735',
#       'name': 'History Museum',
#       'pluralName': 'History Museums',
#       'shortName': 'History Museum',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/museum_history_',
#        'suffix': '.png'},
# ...

# %% [markdown]
# #### Cleaning the data frame of the fifth search - 'Top Picks':

# %%
# assigning relevant part of JSON to venues
venues = Top_picks['response']['venues']

# %%
# tranforming venues into a dataframe
Top_picks_dataframe = json_normalize(venues)
Top_picks_dataframe.head()
# Out:
# /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages/ipykernel_launcher.py:2: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#                          id                               name  \
# 0  4b058660f964a5204b5f22e3             Fire Museum of Memphis
# 1  4b97e10bf964a520291c35e3           Cotton Museum of Memphis
# 2  4b87f667f964a52076d531e3  Belz Museum of Asian & Judaic Art
# 3  4b5f46d3f964a52075b129e3                 Rock'n'Soul Museum
# 4  4bc49fd0461576b0d32b8032           Mississippi River Museum
#
#                                           categories    referralId  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d190941735', 'name': 'H...  v-1587184844    False
# 1  [{'id': '4bf58dd8d48988d190941735', 'name': 'H...  v-1587184844    False
# 2  [{'id': '4bf58dd8d48988d181941735', 'name': 'M...  v-1587184844    False
# 3  [{'id': '4bf58dd8d48988d190941735', 'name': 'H...  v-1587184844    False
# ...

# %%
# keeping only columns that include venue name, and anything that is associated with location
Top_picks_clean_columns = ['name', 'categories'] + [col for col in Top_picks_dataframe.columns if col.startswith('location.')]+ ['id']
clean_Top_picks_dataframe = Top_picks_dataframe.loc[:,Top_picks_clean_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list5 = row['categories']
    except:
        categories_list5 = row['venue.categories']
        
    if len(categories_list5) == 0:
        return None
    else:
        return categories_list5[0]['name']

# filtering the category for each row
clean_Top_picks_dataframe['categories'] = clean_Top_picks_dataframe.apply(get_category_type, axis=1)

# cleaning column names by keeping only last term
clean_Top_picks_dataframe.columns = [column.split('.')[-1] for column in clean_Top_picks_dataframe.columns]

clean_Top_picks_dataframe.head()
# Out:
#                                 name      categories         address  \
# 0             Fire Museum of Memphis  History Museum   118 Adams Ave
# 1           Cotton Museum of Memphis  History Museum    65 Union Ave
# 2  Belz Museum of Asian & Judaic Art          Museum   119 S Main St
# 3                 Rock'n'Soul Museum  History Museum    191 Beale St
# 4           Mississippi River Museum          Museum  125 N Front St
#
#          lat        lng                                     labeledLatLngs  \
# 0  35.148367 -90.050699  [{'label': 'display', 'lat': 35.148367, 'lng':...
# 1  35.143515 -90.054718  [{'label': 'display', 'lat': 35.14351543035522...
# 2  35.141874 -90.054437  [{'label': 'display', 'lat': 35.14187359971947...
# 3  35.138997 -90.052141  [{'label': 'display', 'lat': 35.13899723395392...
# 4  35.149115 -90.054715  [{'label': 'display', 'lat': 35.14911467184522...
#
#    distance postalCode  cc     city state        country  \
# ...

# %%
# deleting unnecessary columns
clean_Top_picks_dataframe2= clean_Top_picks_dataframe.drop(['cc', 'country', 'distance', 'crossStreet','formattedAddress',\
                                        'labeledLatLngs', 'id'], axis=1)
clean_Top_picks_dataframe2
# Out:
#                                   name           categories         address  \
# 0               Fire Museum of Memphis       History Museum   118 Adams Ave
# 1             Cotton Museum of Memphis       History Museum    65 Union Ave
# 2    Belz Museum of Asian & Judaic Art               Museum   119 S Main St
# 3                   Rock'n'Soul Museum       History Museum    191 Beale St
# 4             Mississippi River Museum               Museum  125 N Front St
# 5                     Museum Gift Shop                 None             NaN
# 6  Withers Collection Museum & Gallery           Art Museum    333 Beale St
# 7   W.C. Handy's Memphis Home & Museum  Monument / Landmark    352 Beale St
# 8           Ewing Entertainment Museum       History Museum             NaN
#
#          lat        lng postalCode     city state
# 0  35.148367 -90.050699      38103  Memphis    TN
# 1  35.143515 -90.054718      38103  Memphis    TN
# 2  35.141874 -90.054437      38103  Memphis    TN
# ...

# %%
# deleting rows which its category is not Museum 
df_Top_picks = clean_Top_picks_dataframe2
df_Top_picks
# Out:
#                                   name           categories         address  \
# 0               Fire Museum of Memphis       History Museum   118 Adams Ave
# 1             Cotton Museum of Memphis       History Museum    65 Union Ave
# 2    Belz Museum of Asian & Judaic Art               Museum   119 S Main St
# 3                   Rock'n'Soul Museum       History Museum    191 Beale St
# 4             Mississippi River Museum               Museum  125 N Front St
# 5                     Museum Gift Shop                 None             NaN
# 6  Withers Collection Museum & Gallery           Art Museum    333 Beale St
# 7   W.C. Handy's Memphis Home & Museum  Monument / Landmark    352 Beale St
# 8           Ewing Entertainment Museum       History Museum             NaN
#
#          lat        lng postalCode     city state
# 0  35.148367 -90.050699      38103  Memphis    TN
# 1  35.143515 -90.054718      38103  Memphis    TN
# 2  35.141874 -90.054437      38103  Memphis    TN
# ...

# %%
# deleting rows with none values
df_Top_picks = clean_Top_picks_dataframe2.dropna(axis=0, how='any', thresh=None, subset=None, inplace=False)
df_Top_picks
# Out:
#                                   name           categories         address  \
# 0               Fire Museum of Memphis       History Museum   118 Adams Ave
# 1             Cotton Museum of Memphis       History Museum    65 Union Ave
# 2    Belz Museum of Asian & Judaic Art               Museum   119 S Main St
# 3                   Rock'n'Soul Museum       History Museum    191 Beale St
# 4             Mississippi River Museum               Museum  125 N Front St
# 6  Withers Collection Museum & Gallery           Art Museum    333 Beale St
# 7   W.C. Handy's Memphis Home & Museum  Monument / Landmark    352 Beale St
#
#          lat        lng postalCode     city state
# 0  35.148367 -90.050699      38103  Memphis    TN
# 1  35.143515 -90.054718      38103  Memphis    TN
# 2  35.141874 -90.054437      38103  Memphis    TN
# 3  35.138997 -90.052141      38103  Memphis    TN
# 4  35.149115 -90.054715      38103  Memphis    TN
# 6  35.139158 -90.050266      38103  Memphis    TN
# ...

# %% [markdown]
# ## Sixth search for 'my Fun option-Gym/Fitness Center' :-

# %%
# searching for Fun
search_query = 'Gym/Fitness center'
radius = 1000

# %%
# Defining the corresponding URL
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude1, longitude1, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=TJZPZ1S54SRN0K4YRUZR3JHSBBR05JH4B4V4KWKLBKIQDS04&client_secret=TZN5E2IAWQR1TYI10D2DS2KYGS31RVEGMQXXISYFPDIODM1S&ll=35.1490215,-90.0516285&v=20180604&query=Gym/Fitness center&radius=1000&limit=100'

# %% [markdown]
# ### Cleaning the data frame of the sixth search: 'Fun':

# %%
# Sending the GET Request and examine the results
Fun_results = requests.get(url).json()
Fun_results
# Out:
# {'meta': {'code': 200, 'requestId': '5e9a8314dd0f85001b2d03c7'},
#  'response': {'venues': [{'id': '4e1ba59ee4cd1f7c5d79a023',
#     'name': 'Comfort Inn Fitness Center',
#     'location': {'lat': 35.148252513438926,
#      'lng': -90.05298658831597,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 35.148252513438926,
#        'lng': -90.05298658831597}],
#      'distance': 150,
#      'cc': 'US',
#      'city': 'Memphis',
#      'state': 'TN',
#      'country': 'United States',
#      'formattedAddress': ['Memphis, TN', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d132951735',
#       'name': 'Hotel Pool',
#       'pluralName': 'Hotel Pools',
#       'shortName': 'Pool',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/pool_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1587184845',
#     'hasPerk': False},
#    {'id': '4b05865ff964a520e95e22e3',
# ...

# %%
# assigning relevant part of JSON to venues
venues = Fun_results['response']['venues']

# tranforming venues into a dataframe
Fun_dataframe = json_normalize(venues)
Fun_dataframe.head()
# Out:
# /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages/ipykernel_launcher.py:5: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   """
#                          id                               name  \
# 0  4e1ba59ee4cd1f7c5d79a023         Comfort Inn Fitness Center
# 1  4b05865ff964a520e95e22e3          Sheraton Memphis Downtown
# 2  51e49286498e26ccb0624c8b  Courtyard Marriott Fitness Center
# 3  4b16f9d3f964a52059c023e3        court square fitness center
# 4  5b37a260840fc2002cc69296   SpringHill Suites Fitness Center
#
#                                           categories    referralId  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d132951735', 'name': 'H...  v-1587184845    False
# 1  [{'id': '4bf58dd8d48988d1fa931735', 'name': 'H...  v-1587184845    False
# 2  [{'id': '4bf58dd8d48988d175941735', 'name': 'G...  v-1587184845    False
# 3                                                 []  v-1587184845    False
# ...

# %%
# keeping only columns that include venue name, and anything that is associated with location
Fun_clean_columns = ['name', 'categories'] + [col for col in Fun_dataframe.columns if col.startswith('location.')]+ ['id']
clean_Fun_dataframe = Fun_dataframe.loc[:,Fun_clean_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list5 = row['categories']
    except:
        categories_list5 = row['venue.categories']
        
    if len(categories_list5) == 0:
        return None
    else:
        return categories_list5[0]['name']

# filtering the category for each row
clean_Fun_dataframe['categories'] = clean_Fun_dataframe.apply(get_category_type, axis=1)

# cleaning column names by keeping only last term
clean_Fun_dataframe.columns = [column.split('.')[-1] for column in clean_Fun_dataframe.columns]

clean_Fun_dataframe.head()
# Out:
#                                 name            categories        lat  \
# 0         Comfort Inn Fitness Center            Hotel Pool  35.148253
# 1          Sheraton Memphis Downtown                 Hotel  35.151554
# 2  Courtyard Marriott Fitness Center  Gym / Fitness Center  35.147114
# 3        court square fitness center                  None  35.146824
# 4   SpringHill Suites Fitness Center                 Hotel  35.146005
#
#          lng                                     labeledLatLngs  distance  cc  \
# 0 -90.052987  [{'label': 'display', 'lat': 35.14825251343892...       150  US
# 1 -90.049635  [{'label': 'display', 'lat': 35.151554, 'lng':...       335  US
# 2 -90.052298  [{'label': 'display', 'lat': 35.14711408785812...       220  US
# 3 -90.051772  [{'label': 'display', 'lat': 35.146824, 'lng':...       244  US
# 4 -90.052795  [{'label': 'display', 'lat': 35.146005, 'lng':...       352  US
#
#       city state        country  \
# 0  Memphis    TN  United States
# ...

# %%
# deleting unnecessary columns
clean_Fun_dataframe2= clean_Fun_dataframe.drop(['cc', 'distance', 'country','formattedAddress',\
                                        'labeledLatLngs', 'id'], axis=1)
clean_Fun_dataframe2
# Out:
#                                       name            categories        lat  \
# 0               Comfort Inn Fitness Center            Hotel Pool  35.148253
# 1                Sheraton Memphis Downtown                 Hotel  35.151554
# 2        Courtyard Marriott Fitness Center  Gym / Fitness Center  35.147114
# 3              court square fitness center                  None  35.146824
# 4         SpringHill Suites Fitness Center                 Hotel  35.146005
# 5              Hotel Indigo Fitness Center                 Hotel  35.145611
# 6                  Sheraton Fitness Center  Gym / Fitness Center  35.151648
# 7   Fitness Center at the Doubletree Hotel  Gym / Fitness Center  35.142023
# 8      Hampton Inn & Suites Fitness Center  Gym / Fitness Center  35.140010
# 9            Hotel Indigo Memphis Downtown                 Hotel  35.145326
# 10              AZ Employee Fitness Center  Gym / Fitness Center  35.142161
#
# ...

# %%
# deleting rows which its category is not Gym/Fitness center
df_Fun = clean_Fun_dataframe2
df_Fun
# Out:
#                                       name            categories        lat  \
# 0               Comfort Inn Fitness Center            Hotel Pool  35.148253
# 1                Sheraton Memphis Downtown                 Hotel  35.151554
# 2        Courtyard Marriott Fitness Center  Gym / Fitness Center  35.147114
# 3              court square fitness center                  None  35.146824
# 4         SpringHill Suites Fitness Center                 Hotel  35.146005
# 5              Hotel Indigo Fitness Center                 Hotel  35.145611
# 6                  Sheraton Fitness Center  Gym / Fitness Center  35.151648
# 7   Fitness Center at the Doubletree Hotel  Gym / Fitness Center  35.142023
# 8      Hampton Inn & Suites Fitness Center  Gym / Fitness Center  35.140010
# 9            Hotel Indigo Memphis Downtown                 Hotel  35.145326
# 10              AZ Employee Fitness Center  Gym / Fitness Center  35.142161
#
# ...

# %%
# deleting rows with none values
df_Fun = clean_Fun_dataframe2.dropna(axis=0, how='any', thresh=None, subset=None, inplace=False)
df_Fun
# Out:
#                                      name            categories        lat  \
# 1               Sheraton Memphis Downtown                 Hotel  35.151554
# 4        SpringHill Suites Fitness Center                 Hotel  35.146005
# 7  Fitness Center at the Doubletree Hotel  Gym / Fitness Center  35.142023
# 8     Hampton Inn & Suites Fitness Center  Gym / Fitness Center  35.140010
# 9           Hotel Indigo Memphis Downtown                 Hotel  35.145326
#
#          lng     city state             address postalCode
# 1 -90.049635  Memphis    TN       250 N Main St      38103
# 4 -90.052795  Memphis    TN        85 Court Ave      38103
# 7 -90.050803  Memphis    TN       185 Union Ave      38103
# 8 -90.051651  Memphis    TN      175 Peabody Pl      38103
# 9 -90.049544  Memphis    TN  22 N B B King Blvd      38103

# %% [markdown]
# ## Seventh search for 'Nightlife':

# %%
# searching for Nightlife
search_query = 'Night Life'
radius = 1000

# %%
# Defining the corresponding URL
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude1, longitude1, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=TJZPZ1S54SRN0K4YRUZR3JHSBBR05JH4B4V4KWKLBKIQDS04&client_secret=TZN5E2IAWQR1TYI10D2DS2KYGS31RVEGMQXXISYFPDIODM1S&ll=35.1490215,-90.0516285&v=20180604&query=Night Life&radius=1000&limit=100'

# %%
# Sending the GET Request and examine the results
Nightlife = requests.get(url).json()
Nightlife
# Out:
# {'meta': {'code': 200, 'requestId': '5e9a844e9388d70024001d29'},
#  'response': {'venues': [{'id': '5440d59f498e9cef426951fd',
#     'name': 'Trolley Night',
#     'location': {'lat': 35.1495343,
#      'lng': -90.0489801,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 35.1495343,
#        'lng': -90.0489801}],
#      'distance': 247,
#      'cc': 'US',
#      'city': 'Memphis',
#      'state': 'TN',
#      'country': 'United States',
#      'formattedAddress': ['Memphis, TN', 'United States']},
#     'categories': [],
#     'referralId': 'v-1587184846',
#     'hasPerk': False},
#    {'id': '4b058660f964a5200b5f22e3',
#     'name': "Alfred's on Beale",
#     'location': {'address': '197 Beale St',
#      'crossStreet': 'at 3rd St',
#      'lat': 35.13935583193797,
#      'lng': -90.05150645971298,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 35.13935583193797,
#        'lng': -90.05150645971298},
# ...

# %% [markdown]
# ### Cleaning the seventh data frame of 'Nightlife'

# %%
# assigning relevant part of JSON to venues
venues = Nightlife['response']['venues']

# tranforming venues into a dataframe
Nightlife_dataframe = json_normalize(venues)
Nightlife_dataframe.head()
# Out:
# /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages/ipykernel_launcher.py:5: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   """
#                          id                           name  \
# 0  5440d59f498e9cef426951fd                  Trolley Night
# 1  4b058660f964a5200b5f22e3              Alfred's on Beale
# 2  4d5f2f735c39b1f785f2f449                    Purple Haze
# 3  4f326c8d19836c91c7d6750d  Healthy Life Styles Food Bstr
# 4  4b9c1a36f964a520484a36e3                High Life Lanes
#
#                                           categories    referralId  hasPerk  \
# 0                                                 []  v-1587184846    False
# 1  [{'id': '4bf58dd8d48988d116941735', 'name': 'B...  v-1587184846    False
# 2  [{'id': '4bf58dd8d48988d11f941735', 'name': 'N...  v-1587184846    False
# 3  [{'id': '4d4b7105d754a06374d81259', 'name': 'F...  v-1587184846    False
# ...

# %%
# keeping only columns that include venue name, and anything that is associated with location
Nightlife_clean_columns = ['name', 'categories'] + [col for col in Nightlife_dataframe.columns if col.startswith('location.')]+ ['id']
clean_Nightlife_dataframe = Nightlife_dataframe.loc[:,Nightlife_clean_columns]

# functioning that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list5 = row['categories']
    except:
        categories_list5 = row['venue.categories']
        
    if len(categories_list5) == 0:
        return None
    else:
        return categories_list5[0]['name']

# filtering the category for each row
clean_Nightlife_dataframe['categories'] = clean_Nightlife_dataframe.apply(get_category_type, axis=1)

# cleaning column names by keeping only last term
clean_Nightlife_dataframe.columns = [column.split('.')[-1] for column in clean_Nightlife_dataframe.columns]

clean_Nightlife_dataframe.head()
# Out:
#                             name     categories        lat        lng  \
# 0                  Trolley Night           None  35.149534 -90.048980
# 1              Alfred's on Beale            Bar  35.139356 -90.051506
# 2                    Purple Haze      Nightclub  35.138941 -90.053773
# 3  Healthy Life Styles Food Bstr           Food  35.143946 -90.053421
# 4                High Life Lanes  Bowling Alley  35.140847 -90.053025
#
#                                       labeledLatLngs  distance  cc     city  \
# 0  [{'label': 'display', 'lat': 35.1495343, 'lng'...       247  US  Memphis
# 1  [{'label': 'display', 'lat': 35.13935583193797...      1076  US  Memphis
# 2  [{'label': 'display', 'lat': 35.13894135027829...      1138  US  Memphis
# 3  [{'label': 'display', 'lat': 35.143946, 'lng':...       588  US  Memphis
# 4  [{'label': 'display', 'lat': 35.140847, 'lng':...       918  US  Memphis
#
#   state        country                                   formattedAddress  \
# ...

# %%
# deleting unnecessary columns
clean_Nightlife_dataframe2= clean_Nightlife_dataframe.drop(['cc', 'distance','crossStreet','country','formattedAddress',\
                                        'labeledLatLngs', 'id'], axis=1)
clean_Nightlife_dataframe2
# Out:
#                             name     categories        lat        lng  \
# 0                  Trolley Night           None  35.149534 -90.048980
# 1              Alfred's on Beale            Bar  35.139356 -90.051506
# 2                    Purple Haze      Nightclub  35.138941 -90.053773
# 3  Healthy Life Styles Food Bstr           Food  35.143946 -90.053421
# 4                High Life Lanes  Bowling Alley  35.140847 -90.053025
#
#       city state                     address postalCode
# 0  Memphis    TN                         NaN        NaN
# 1  Memphis    TN                197 Beale St      38103
# 2  Memphis    TN  140 Lt. George W. Lee Ave.      38103
# 3  Memphis    TN                45 S Main St      38103
# 4  Memphis    TN              150 Peabody Pl      38103

# %%
# deleting rows which its category is not Nightlife
df_Nightlife = clean_Nightlife_dataframe2
df_Nightlife
# Out:
#                             name     categories        lat        lng  \
# 0                  Trolley Night           None  35.149534 -90.048980
# 1              Alfred's on Beale            Bar  35.139356 -90.051506
# 2                    Purple Haze      Nightclub  35.138941 -90.053773
# 3  Healthy Life Styles Food Bstr           Food  35.143946 -90.053421
# 4                High Life Lanes  Bowling Alley  35.140847 -90.053025
#
#       city state                     address postalCode
# 0  Memphis    TN                         NaN        NaN
# 1  Memphis    TN                197 Beale St      38103
# 2  Memphis    TN  140 Lt. George W. Lee Ave.      38103
# 3  Memphis    TN                45 S Main St      38103
# 4  Memphis    TN              150 Peabody Pl      38103

# %%
# deleting rows with none values
df_Nightlife = clean_Nightlife_dataframe2.dropna(axis=0, how='any', thresh=None, subset=None, inplace=False)
df_Nightlife
# Out:
#                             name     categories        lat        lng  \
# 1              Alfred's on Beale            Bar  35.139356 -90.051506
# 2                    Purple Haze      Nightclub  35.138941 -90.053773
# 3  Healthy Life Styles Food Bstr           Food  35.143946 -90.053421
# 4                High Life Lanes  Bowling Alley  35.140847 -90.053025
#
#       city state                     address postalCode
# 1  Memphis    TN                197 Beale St      38103
# 2  Memphis    TN  140 Lt. George W. Lee Ave.      38103
# 3  Memphis    TN                45 S Main St      38103
# 4  Memphis    TN              150 Peabody Pl      38103

# %% [markdown]
# ## Eighth search of ' Breakfast'

# %%
# searching for Breakfast
search_query = 'Breakfast'
radius = 1000

# %%
# Defining the corresponding URL
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude1, longitude1, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=TJZPZ1S54SRN0K4YRUZR3JHSBBR05JH4B4V4KWKLBKIQDS04&client_secret=TZN5E2IAWQR1TYI10D2DS2KYGS31RVEGMQXXISYFPDIODM1S&ll=35.1490215,-90.0516285&v=20180604&query=Breakfast&radius=1000&limit=100'

# %%
# Sending the GET Request and examining the results
Breakfast = requests.get(url).json()
Breakfast
# Out:
# {'meta': {'code': 200, 'requestId': '5e9a8421e826ac001b39e2d7'},
#  'response': {'venues': [{'id': '5975fe5835811b1c185ffe5e',
#     'name': 'Comfort In Downtown Breakfast Area',
#     'location': {'address': '100 N Front St, Memphis, TN 38103, USA',
#      'crossStreet': '(at Jefferson)',
#      'lat': 35.147797,
#      'lng': -90.05155,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 35.147797,
#        'lng': -90.05155}],
#      'distance': 136,
#      'postalCode': '38103',
#      'cc': 'US',
#      'city': 'Memphis',
#      'state': 'TN',
#      'country': 'United States',
#      'formattedAddress': ['100 N Front St, Memphis, TN 38103, USA ((at Jefferson))',
#       'Memphis, TN 38103',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d143941735',
#       'name': 'Breakfast Spot',
#       'pluralName': 'Breakfast Spots',
#       'shortName': 'Breakfast',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/breakfast_',
# ...

# %% [markdown]
# Cleaning the eight search - 'Nightlife' :

# %%
# assigning relevant part of JSON to venues
venues = Breakfast['response']['venues']

# tranforming venues into a dataframe
Breakfast_dataframe = json_normalize(venues)
Breakfast_dataframe.head()
# Out:
# /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages/ipykernel_launcher.py:5: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   """
#                          id                                          name  \
# 0  5975fe5835811b1c185ffe5e            Comfort In Downtown Breakfast Area
# 1  5325b3ca498ed7133ad46f7b                              Breakfast Buffet
# 2  4e91a44ff79014e2cef6d98d              Springhill Suites Breakfast Room
# 3  4e91a59646908c033f94aba4  Springhill Suites Delicious Breakfast Buffet
# 4  4ee75b37b634710b8d9c22a1                      Hampton's Breakfast Area
#
#                                           categories    referralId  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d143941735', 'name': 'B...  v-1587184847    False
# 1  [{'id': '4bf58dd8d48988d16d941735', 'name': 'C...  v-1587184847    False
# 2  [{'id': '4bf58dd8d48988d143941735', 'name': 'B...  v-1587184847    False
# ...

# %%
# keeping only columns that include venue name, and anything that is associated with location
Breakfast_clean_columns = ['name', 'categories'] + [col for col in Breakfast_dataframe.columns if col.startswith('location.')]+ ['id']
clean_Breakfast_dataframe = Breakfast_dataframe.loc[:,Breakfast_clean_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list5 = row['categories']
    except:
        categories_list5 = row['venue.categories']
        
    if len(categories_list5) == 0:
        return None
    else:
        return categories_list5[0]['name']

# filtering the category for each row
clean_Breakfast_dataframe['categories'] = clean_Breakfast_dataframe.apply(get_category_type, axis=1)

# cleaning column names by keeping only last term
clean_Breakfast_dataframe.columns = [column.split('.')[-1] for column in clean_Breakfast_dataframe.columns]

clean_Breakfast_dataframe.head()
# Out:
#                                            name      categories  \
# 0            Comfort In Downtown Breakfast Area  Breakfast Spot
# 1                              Breakfast Buffet            Café
# 2              Springhill Suites Breakfast Room  Breakfast Spot
# 3  Springhill Suites Delicious Breakfast Buffet  Breakfast Spot
# 4                      Hampton's Breakfast Area  Breakfast Spot
#
#                                   address     crossStreet        lat  \
# 0  100 N Front St, Memphis, TN 38103, USA  (at Jefferson)  35.147797
# 1                                     NaN             NaN  35.151847
# 2                                     NaN             NaN  35.146378
# 3                                     NaN             NaN  35.146239
# 4                           175 E Peabody             NaN  35.139965
#
#          lng                                     labeledLatLngs  distance  \
# 0 -90.051550  [{'label': 'display', 'lat': 35.147797, 'lng':...       136
# ...

# %%
# deleting unnecessary columns
clean_Breakfast_dataframe2= clean_Breakfast_dataframe.drop(['cc', 'distance','crossStreet', 'country','formattedAddress',\
                                        'labeledLatLngs', 'id'], axis=1)
clean_Breakfast_dataframe2
# Out:
#                                            name      categories  \
# 0            Comfort In Downtown Breakfast Area  Breakfast Spot
# 1                              Breakfast Buffet            Café
# 2              Springhill Suites Breakfast Room  Breakfast Spot
# 3  Springhill Suites Delicious Breakfast Buffet  Breakfast Spot
# 4                      Hampton's Breakfast Area  Breakfast Spot
#
#                                   address        lat        lng postalCode  \
# 0  100 N Front St, Memphis, TN 38103, USA  35.147797 -90.051550      38103
# 1                                     NaN  35.151847 -90.048342        NaN
# 2                                     NaN  35.146378 -90.052348        NaN
# 3                                     NaN  35.146239 -90.052695        NaN
# 4                           175 E Peabody  35.139965 -90.052011      38103
#
#       city      state
# 0  Memphis         TN
# 1  Memphis         TN
# 2      NaN  Tennessee
# 3  Memphis         TN
# ...

# %%
# deleting rows which its category is not Breakfast
df_Breakfast = clean_Breakfast_dataframe2
df_Breakfast
# Out:
#                                            name      categories  \
# 0            Comfort In Downtown Breakfast Area  Breakfast Spot
# 1                              Breakfast Buffet            Café
# 2              Springhill Suites Breakfast Room  Breakfast Spot
# 3  Springhill Suites Delicious Breakfast Buffet  Breakfast Spot
# 4                      Hampton's Breakfast Area  Breakfast Spot
#
#                                   address        lat        lng postalCode  \
# 0  100 N Front St, Memphis, TN 38103, USA  35.147797 -90.051550      38103
# 1                                     NaN  35.151847 -90.048342        NaN
# 2                                     NaN  35.146378 -90.052348        NaN
# 3                                     NaN  35.146239 -90.052695        NaN
# 4                           175 E Peabody  35.139965 -90.052011      38103
#
#       city      state
# 0  Memphis         TN
# 1  Memphis         TN
# 2      NaN  Tennessee
# 3  Memphis         TN
# ...

# %%
# deleting rows with none values
df_Breakfast = clean_Breakfast_dataframe2.dropna(axis=0, how='any', thresh=None, subset=None, inplace=False)
df_Breakfast
# Out:
#                                  name      categories  \
# 0  Comfort In Downtown Breakfast Area  Breakfast Spot
#
#                                   address        lat       lng postalCode  \
# 0  100 N Front St, Memphis, TN 38103, USA  35.147797 -90.05155      38103
#
#       city state
# 0  Memphis    TN

# %% [markdown]
# ### Generate map to visualize hotels, shopping stores and Cafeteria and how they cluster together

# %% [markdown]
# # 3.Clustering: Creating aerial / geographical location map view-for multi clusters combination options:

# %% [markdown]
# ## 3.1 Cluster 1: Combining Food,Cafeteria and Restaurant venues :

# %%
# creating dataframe of food, Cafeteria and Restaurant
food_neighbourhood_df = pd.concat([df_food, df_Cafeteria, df_Restaurant], ignore_index=True)
food_neighbourhood_df
# Out:
#                                            name  \
# 0                          Easy Way Food Stores
# 1                 Healthy Life Styles Food Bstr
# 2                              Gli Food Service
# 3                             Premier Cafeteria
# 4                             The MED Cafeteria
# 5                             Peabody Cafeteria
# 6                          Piccadilly Cafeteria
# 7                          Piccadilly Cafeteria
# 8                Flight Restaurant and Wine Bar
# 9                    Bleu Restaurant and Lounge
# 10                            Arcade Restaurant
# 11                          Gridiron Restaurant
# 12                              SAGE Restaurant
# 13                            Huey's Restaurant
# 14            Ms. Girlee's Soul Food Restaurant
# 15                 Felicia Suzanne's Restaurant
# 16        Notes & Provisions Restaurant and Bar
# 17                    Smitty's Place Restaurant
# ...

# %%
# Generate map to visualize food neighbourhood including restaurant and Cafeteria 
food_map = folium.Map(location=[latitude1, longitude1], zoom_start=14)

for lat, lng, name, categories, address in zip(food_neighbourhood_df['lat'], food_neighbourhood_df['lng'], 
                                           food_neighbourhood_df['name'], food_neighbourhood_df['categories'],\
                                               food_neighbourhood_df['address']):
    label = '{}, {}'.format(name, address)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='blue',
        fill_opacity=0.7,
        parse_html=False).add_to(food_map)  
    
food_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
food_neighbourhood_df.shape
# Out:
# (50, 8)

# %% [markdown]
# ## 3.2 Cluster 2: Combining Park,Restaurant,Cafeteria and my Top Pick-Museum venues:

# %%
# creating dataframe of Park, Restaurant and Cafeteria
park_neighbourhood_df = pd.concat([df_park, df_Restaurant, df_Cafeteria,df_Top_picks], ignore_index=True)
park_neighbourhood_df
# Out:
#                                    name           categories  \
# 0                          Memphis Park                 Park
# 1                          Tom Lee Park                 Park
# 2      Mississippi River Greenbelt Park                 Park
# 3                    Robert Church Park                 Park
# 4                 Mud Island River Park                 Park
# ..                                  ...                  ...
# 61    Belz Museum of Asian & Judaic Art               Museum
# 62                   Rock'n'Soul Museum       History Museum
# 63             Mississippi River Museum               Museum
# 64  Withers Collection Museum & Gallery           Art Museum
# 65   W.C. Handy's Memphis Home & Museum  Monument / Landmark
#
#                     address        lat        lng postalCode     city state
# 0               51 Front St  35.146732 -90.054067      38103  Memphis    TN
# 1   357 South Riverside Dr.  35.136636 -90.062896      38103  Memphis    TN
# ...

# %%
# Generating map to visualize park neighbourhood including Restaurant and Cafeteria 
park_map = folium.Map(location=[latitude1, longitude1], zoom_start=14)

for lat, lng, name, categories, address in zip(park_neighbourhood_df['lat'], park_neighbourhood_df['lng'], 
                                           park_neighbourhood_df['name'], park_neighbourhood_df['categories'],\
                                               park_neighbourhood_df['address']):
    label = '{}, {}'.format(name, address)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='blue',
        fill_opacity=0.7,
        parse_html=False).add_to(park_map)  
    
park_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
park_neighbourhood_df.shape
# Out:
# (66, 8)

# %% [markdown]
# ## 3.3 Cluster 3: Combining Food,Restaurant,Cafeteria and Breakfast venues:

# %%
# creating dataframe of food, Restaurant,Cafeteria and Breakfast categories
Hotel_neighbourhood_df = pd.concat([df_food, df_Restaurant, df_Cafeteria,df_Breakfast], ignore_index=True)
Hotel_neighbourhood_df
# Out:
#                                            name  \
# 0                          Easy Way Food Stores
# 1                 Healthy Life Styles Food Bstr
# 2                              Gli Food Service
# 3                Flight Restaurant and Wine Bar
# 4                    Bleu Restaurant and Lounge
# 5                             Arcade Restaurant
# 6                           Gridiron Restaurant
# 7                               SAGE Restaurant
# 8                             Huey's Restaurant
# 9             Ms. Girlee's Soul Food Restaurant
# 10                 Felicia Suzanne's Restaurant
# 11        Notes & Provisions Restaurant and Bar
# 12                    Smitty's Place Restaurant
# 13                    Harbor Landing Restaurant
# 14                     Erikas German Restaurant
# 15              Orleans On The Front Restaurant
# 16                      Cayenne Moon Restaurant
# 17             Christian Supper Club Restaurant
# ...

# %%
# Generate map to visualize food neighbourhood including Restaurant,Breakfast and Cafeteria 
Hotel_map = folium.Map(location=[latitude1, longitude1], zoom_start=14)

for lat, lng, name, categories, address in zip(Hotel_neighbourhood_df['lat'], Hotel_neighbourhood_df['lng'], 
                                           Hotel_neighbourhood_df['name'], Hotel_neighbourhood_df['categories'],\
                                               Hotel_neighbourhood_df['address']):
    label = '{}, {}'.format(name, address)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='Green',
        fill=True,
        fill_color='Green',
        fill_opacity=0.7,
        parse_html=False).add_to(Hotel_map)  
    
Hotel_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
Hotel_neighbourhood_df.shape
# Out:
# (51, 8)

# %% [markdown]
# ## 3.4 Cluster 4: Combining Fun-Gym/Fitness Center , my Top Pick-Museum and Nightlife venues :

# %%
# creating dataframe of Park, Restaurant and Cafeteria
Visit_neighbourhood_df = pd.concat([df_Fun, df_Top_picks, df_Nightlife], ignore_index=True)
Visit_neighbourhood_df
# Out:
#                                       name            categories        lat  \
# 0                Sheraton Memphis Downtown                 Hotel  35.151554
# 1         SpringHill Suites Fitness Center                 Hotel  35.146005
# 2   Fitness Center at the Doubletree Hotel  Gym / Fitness Center  35.142023
# 3      Hampton Inn & Suites Fitness Center  Gym / Fitness Center  35.140010
# 4            Hotel Indigo Memphis Downtown                 Hotel  35.145326
# 5                   Fire Museum of Memphis        History Museum  35.148367
# 6                 Cotton Museum of Memphis        History Museum  35.143515
# 7        Belz Museum of Asian & Judaic Art                Museum  35.141874
# 8                       Rock'n'Soul Museum        History Museum  35.138997
# 9                 Mississippi River Museum                Museum  35.149115
# 10     Withers Collection Museum & Gallery            Art Museum  35.139158
# ...

# %%
# Generating map to visualize park neighbourhood including Restaurant ,Cafeteria and Breakfast categories 
Visit_map = folium.Map(location=[latitude1, longitude1], zoom_start=14)

for lat, lng, name, categories, address in zip(Visit_neighbourhood_df['lat'], Visit_neighbourhood_df['lng'], 
                                           Visit_neighbourhood_df['name'], Visit_neighbourhood_df['categories'],\
                                               Visit_neighbourhood_df['address']):
    label = '{}, {}'.format(name, address)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='Red',
        fill=True,
        fill_color='Red',
        fill_opacity=0.7,
        parse_html=False).add_to(Visit_map)  
    
Visit_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
Visit_neighbourhood_df.shape
# Out:
# (16, 8)

# %% [markdown]
# ## 4.Conclusion:

# %% [markdown]
# Above execrcise carried out as a pilot clustering and view with combined option for one city, keeping in mind that to be extended with multi cities combination or for comparison for user need for quicker overall view and decision.     ( In 2.1 - we had created for 2 cities as an example with url1 & url2 , but 2.2 onwards for easier working , url1 used as url only but with same latitude &  longitude )

# %% [markdown]
# ### 4.1 Assumption :

# %% [markdown]
# Though above excercise limited with clustering concept with four square API and we will be noticing that initially all libraries are imported for k-means also, may be used for future deep learning.

# %% [markdown]
# May also be noted that -NaN data as fetched from url and got removed based on syntax and not equated or filled with assumed or filled or copied data.

# %% [markdown]
# Category names Food,Park,Cafeteria,Nightlife,Fun & Top Pick are based on Four Square.  ( Shopping- excluded for this proto-type project )

# %% [markdown]
# Catalyst LLC is my dream organization and named for this project learning only.

# %% [markdown]
# ### 5. Thanking:

# %% [markdown]
# ### The codes are most of part of coursera -IBM datascience lab exercises and learning and my sincere thanks to all instructors and IBM for structured coaching and guidelines.

# %% [markdown]
# #### Also thanking our learning peers / data scientists for timely evaluation,sharing and support.
